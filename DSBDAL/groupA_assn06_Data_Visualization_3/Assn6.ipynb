# %% [markdown]
# # Data Visualization III
# Download the Iris flower dataset or any other dataset into a DataFrame. (e.g.,
# https://archive.ics.uci.edu/ml/datasets/Iris).
# Scan the dataset and give the inference as:
# 1. List down the features and their types (e.g., numeric, nominal) available in the dataset.
# 2. Create a histogram for each feature in the dataset to illustrate the feature distributions.
# 3. Create a box plot for each feature in the dataset. Compare distributions and identify
# outliers.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Iris.csv')

# %%
data
# Out:
#       Id  sepal_length  sepal_width  petal_length  petal_width         Species
# 0      1           5.1          3.5           1.4          0.2     Iris-setosa
# 1      2           4.9          3.0           1.4          0.2     Iris-setosa
# 2      3           4.7          3.2           1.3          0.2     Iris-setosa
# 3      4           4.6          3.1           1.5          0.2     Iris-setosa
# 4      5           5.0          3.6           1.4          0.2     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 145  146           6.7          3.0           5.2          2.3  Iris-virginica
# 146  147           6.3          2.5           5.0          1.9  Iris-virginica
# 147  148           6.5          3.0           5.2          2.0  Iris-virginica
# 148  149           6.2          3.4           5.4          2.3  Iris-virginica
# 149  150           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# # Histogram

# %%
sns.histplot(data=data, x="Species", y="sepal_length", kde=True)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='sepal_length'>

# %%
sns.histplot(data=data, x="Species", y="sepal_length")
# Out:
# <AxesSubplot:xlabel='Species', ylabel='sepal_length'>

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 15))

sns.histplot(ax=axes[0, 0], data=data, x="Species", y="sepal_length")
sns.histplot(ax=axes[0, 1], data=data, x='Species', y='sepal_width')
sns.histplot(ax=axes[1, 0], data=data, x='Species', y='petal_length')
sns.histplot(ax=axes[1, 1], data=data, x='Species', y='petal_width')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='petal_width'>

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 15))

sns.histplot(ax=axes[0, 0], data=data, x="sepal_length", hue="Species")
sns.histplot(ax=axes[0, 1], data=data, x='sepal_width', hue="Species")
sns.histplot(ax=axes[1, 0], data=data, x='petal_length', hue="Species")
sns.histplot(ax=axes[1, 1], data=data, x='petal_width', hue="Species")
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Count'>

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 15))

sns.histplot(ax=axes[0, 0], data=data, x="sepal_length", hue="Species", kde="true")
sns.histplot(ax=axes[0, 1], data=data, x='sepal_width', hue="Species", kde="true")
sns.histplot(ax=axes[1, 0], data=data, x='petal_length', hue="Species", kde="true")
sns.histplot(ax=axes[1, 1], data=data, x='petal_width', hue="Species", kde="true")
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Count'>

# %% [markdown]
# # Boxplot

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 15))

sns.boxplot(ax=axes[0, 0], data=data, x="Species", y="sepal_length")
sns.boxplot(ax=axes[0, 1], data=data, x='Species', y='sepal_width')
sns.boxplot(ax=axes[1, 0], data=data, x='Species', y='petal_length')
sns.boxplot(ax=axes[1, 1], data=data, x='Species', y='petal_width')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='petal_width'>

# %%
def find_outlier(arr1):
    q1 = np.quantile(arr1, 0.25)
    q3 = np.quantile(arr1, 0.75)
    med = np.median(arr1)
    
    iqr = q3-q1

    lower_bound = q1 - (1.5*iqr)
    upper_bound = q3 + (1.5*iqr)
    print("IQR= " + str(iqr)  + "\nlower_bound= " + str(lower_bound) + "\nupper_bound= " + str(upper_bound))
    return lower_bound, upper_bound
    
    
def disp_outlier(arr1, lower_bound, upper_bound):
    outliers = arr1[(arr1 <= lower_bound) | (arr1 >= upper_bound)]
    print('The following are the outliers in the boxplot:{}'.format(outliers))

# %%
lower_bound, upper_bound = find_outlier(data["sepal_length"])
# Out:
# IQR= 1.3000000000000007
# lower_bound= 3.1499999999999986
# upper_bound= 8.350000000000001

# %%
(lower_bound, upper_bound)
# Out:
# (3.1499999999999986, 8.350000000000001)

# %%
disp_outlier(data["sepal_length"], lower_bound, upper_bound)
# Out:
# The following are the outliers in the boxplot:Series([], Name: sepal_length, dtype: float64)

# %% [markdown]
# there are no outliers in sepal_length column
