# %% [markdown]
# # Data Wrangling, I
# Perform the following operations using Python on any open-source dataset (e.g., data.csv)
# 1. Import all the required Python Libraries.
# 2. Locate an open-source data from the web (e.g. https://www.kaggle.com). Provide a clear
# description of the data and its source (i.e., URL of the web site).
# 3. Load the Dataset into pandas’ data frame.
# 4. Data Preprocessing: check for missing values in the data using pandas isnull (), describe()
# function to get some initial statistics. Provide variable descriptions. Types of variables etc.
# Check the dimensions of the data frame.
# 5. Data Formatting and Data Normalization: Summarize the types of variables by checking the
# data types (i.e., character, numeric, integer, factor, and logical) of the variables in the data
# set. If variables are not in the correct data type, apply proper type conversions.
# 6. Turn categorical variables into quantitative variables in Python.
# In addition to the codes and outputs, explain every operation that you do in the above steps and
# explain everything that you do to import/read/scrape the data set.

# %%
import pandas as pd
data=pd.read_csv("Cleaned_Laptop_data.csv")

# %%
len(data)
# Out:
# 896

# %%
data.shape
# Out:
# (896, 23)

# %%
data.head()
# Out:
#   brand     model processor_brand processor_name processor_gnrtn ram_gb
# 0  ASUS   Celeron           Intel   Celeron Dual         Missing      4  \
# 1  ASUS  VivoBook           Intel        Core i3            10th      8
# 2  ASUS  Vivobook           Intel        Core i3            10th      8
# 3    HP      Core           Intel        Core i3            11th      8
# 4    HP      Core           Intel        Core i5            11th      8
#
#   ram_type  ssd   hdd       os  ...  display_size  warranty Touchscreen
# 0     DDR4    0  1024  Windows  ...          15.6         1          No  \
# 1     DDR4  512     0  Windows  ...          15.6         1          No
# 2     DDR4    0  1024  Windows  ...          14.1         1          No
# 3     DDR4  512     0  Windows  ...          15.6         1          No
# 4     DDR4  512     0  Windows  ...          15.6         0          No
#
#   msoffice  latest_price old_price discount  star_rating  ratings  reviews
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            896 non-null    object
#  1   model            896 non-null    object
#  2   processor_brand  896 non-null    object
#  3   processor_name   895 non-null    object
#  4   processor_gnrtn  896 non-null    object
#  5   ram_gb           871 non-null    object
#  6   ram_type         871 non-null    object
#  7   ssd              896 non-null    int64
#  8   hdd              896 non-null    int64
#  9   os               896 non-null    object
#  10  os_bit           896 non-null    int64
#  11  graphic_card_gb  896 non-null    int64
#  12  weight           896 non-null    object
#  13  display_size     896 non-null    object
#  14  warranty         896 non-null    int64
#  15  Touchscreen      896 non-null    object
#  16  msoffice         896 non-null    object
# ...

# %%
data.describe()
# Out:
#                ssd          hdd      os_bit  graphic_card_gb    warranty
# count   896.000000   896.000000  896.000000       896.000000  896.000000  \
# mean    431.750000   190.857143   59.178571         1.198661    0.691964
# std     316.436824   401.181158   11.453644         2.057454    0.606282
# min       0.000000     0.000000   32.000000         0.000000    0.000000
# 25%     256.000000     0.000000   64.000000         0.000000    0.000000
# 50%     512.000000     0.000000   64.000000         0.000000    1.000000
# 75%     512.000000     0.000000   64.000000         2.000000    1.000000
# max    3072.000000  2048.000000   64.000000         8.000000    3.000000
#
#         latest_price      old_price    discount  star_rating       ratings
# count     896.000000     896.000000  896.000000   896.000000    896.000000  \
# mean    76309.860491   88134.154018   18.527902     2.980469    367.391741
# std     46613.354368   55719.645554   10.508486     1.965254   1106.309355
# ...

# %%
import numpy as np
data.describe(include=object)
# Out:
#        brand model processor_brand processor_name processor_gnrtn ram_gb
# count    896   896             896            895             896    871  \
# unique    21   120              11             35               8     13
# top     ASUS  Core           Intel        Core i5            11th      8
# freq     254    95             645            292             346    503
#
#        ram_type       os  weight display_size Touchscreen msoffice
# count       871      896     896          896         896      896
# unique       15        3       3           23           2        2
# top        DDR4  Windows  Casual         15.6          No       No
# freq        741      796     566          383         793      606

# %%
data["brand"].value_counts()
# Out:
# brand
# ASUS         254
# DELL         154
# Lenovo       148
# HP           142
# acer          58
# MSI           52
# APPLE         28
# Avita         18
# LG             5
# Vaio           5
# realme         4
# Nokia          4
# Infinix        4
# ALIENWARE      4
# Smartron       3
# lenovo         3
# MICROSOFT      3
# RedmiBook      3
# Mi             2
# SAMSUNG        1
# iball          1
# Name: count, dtype: int64

# %%
data.loc[1]
# Out:
# brand                  ASUS
# model              VivoBook
# processor_brand       Intel
# processor_name      Core i3
# processor_gnrtn        10th
# ram_gb                    8
# ram_type               DDR4
# ssd                     512
# hdd                       0
# os                  Windows
# os_bit                   64
# graphic_card_gb           0
# weight               Casual
# display_size           15.6
# warranty                  1
# Touchscreen              No
# msoffice                 No
# latest_price          37990
# old_price             50990
# discount                 25
# star_rating             4.3
# ratings                 990
# reviews                 108
# Name: 1, dtype: object

# %%
data.iloc[1]
# Out:
# brand                  ASUS
# model              VivoBook
# processor_brand       Intel
# processor_name      Core i3
# processor_gnrtn        10th
# ram_gb                    8
# ram_type               DDR4
# ssd                     512
# hdd                       0
# os                  Windows
# os_bit                   64
# graphic_card_gb           0
# weight               Casual
# display_size           15.6
# warranty                  1
# Touchscreen              No
# msoffice                 No
# latest_price          37990
# old_price             50990
# discount                 25
# star_rating             4.3
# ratings                 990
# reviews                 108
# Name: 1, dtype: object

# %%
data.iloc[0:,0:5]
# Out:
#          brand        model processor_brand     processor_name processor_gnrtn
# 0         ASUS      Celeron           Intel       Celeron Dual         Missing
# 1         ASUS     VivoBook           Intel            Core i3            10th
# 2         ASUS     Vivobook           Intel            Core i3            10th
# 3           HP         Core           Intel            Core i3            11th
# 4           HP         Core           Intel            Core i5            11th
# 5       Lenovo      IdeaPad           Intel            Core i3            10th
# 6           HP          15s             AMD            Ryzen 3         Missing
# 7         ASUS         Core           Intel            Core i3            11th
# 8         DELL       Vostro           Intel            Core i3            10th
# 9       Lenovo      IdeaPad           Intel            Core i3            10th
# 10          HP         Core           Intel            Core i5            11th
# ...

# %%
data.loc[0]
# Out:
# brand                      ASUS
# model                   Celeron
# processor_brand           Intel
# processor_name     Celeron Dual
# processor_gnrtn         Missing
# ram_gb                        4
# ram_type                   DDR4
# ssd                           0
# hdd                        1024
# os                      Windows
# os_bit                       64
# graphic_card_gb               0
# weight                   Casual
# display_size               15.6
# warranty                      1
# Touchscreen                  No
# msoffice                     No
# latest_price              23990
# old_price                 26990
# discount                     11
# star_rating                 3.8
# ratings                   15279
# reviews                    1947
# Name: 0, dtype: object

# %%
data.head()
# Out:
#   brand     model processor_brand processor_name processor_gnrtn ram_gb
# 0  ASUS   Celeron           Intel   Celeron Dual         Missing      4  \
# 1  ASUS  VivoBook           Intel        Core i3            10th      8
# 2  ASUS  Vivobook           Intel        Core i3            10th      8
# 3    HP      Core           Intel        Core i3            11th      8
# 4    HP      Core           Intel        Core i5            11th      8
#
#   ram_type  ssd   hdd       os  ...  display_size  warranty Touchscreen
# 0     DDR4    0  1024  Windows  ...          15.6         1          No  \
# 1     DDR4  512     0  Windows  ...          15.6         1          No
# 2     DDR4    0  1024  Windows  ...          14.1         1          No
# 3     DDR4  512     0  Windows  ...          15.6         1          No
# 4     DDR4  512     0  Windows  ...          15.6         0          No
#
#   msoffice  latest_price old_price discount  star_rating  ratings  reviews
# ...

# %%
data.tail(3)
# Out:
#       brand     model processor_brand processor_name processor_gnrtn ram_gb
# 893      HP  Pavilion           Intel        Core i5             8th      8  \
# 894    ASUS  Vivobook           Intel        Core i3            10th      4
# 895  Lenovo       v15           Intel        Core i3            10th      4
#
#     ram_type  ssd   hdd       os  ...  display_size  warranty Touchscreen
# 893     DDR4  128     0  Windows  ...          13.3         1          No  \
# 894     DDR4    0  1024  Windows  ...          14.1         0          No
# 895     DDR4    0  1024  Missing  ...          15.6         0          No
#
#     msoffice  latest_price old_price discount  star_rating  ratings  reviews
# 893       No         76012         0        0          4.3      129       16
# 894       No         33990     39990       15          3.4       31        6
# 895       No         39999     43999        9          3.1        8        1
#
# [3 rows x 23 columns]

# %%
points=data["latest_price"]
points.sum()
# Out:
# 68373635

# %%
data["latest_price"].mean()
# Out:
# 76309.86049107143

# %%
data["latest_price"].min()
# Out:
# 13990

# %%
data["latest_price"].max()
# Out:
# 441990

# %%
data.isnull()
# Out:
#      brand  model  processor_brand  processor_name  processor_gnrtn  ram_gb
# 0    False  False            False           False            False   False  \
# 1    False  False            False           False            False   False
# 2    False  False            False           False            False   False
# 3    False  False            False           False            False   False
# 4    False  False            False           False            False   False
# 5    False  False            False           False            False   False
# 6    False  False            False           False            False   False
# 7    False  False            False           False            False   False
# 8    False  False            False           False            False   False
# 9    False  False            False           False            False   False
# 10   False  False            False           False            False   False
# ...

# %%
data.isnull().any()
# Out:
# brand              False
# model              False
# processor_brand    False
# processor_name      True
# processor_gnrtn    False
# ram_gb              True
# ram_type            True
# ssd                False
# hdd                False
# os                 False
# os_bit             False
# graphic_card_gb    False
# weight             False
# display_size       False
# warranty           False
# Touchscreen        False
# msoffice           False
# latest_price       False
# old_price          False
# discount           False
# star_rating        False
# ratings            False
# reviews            False
# dtype: bool

# %%
np_array=data.to_numpy()
print(type(np_array))
# Out:
# <class 'numpy.ndarray'>

# %%
arr1=np.array([["atharv",1,2,3,4],[5,6,7,8,9]])

# %%
print(arr1[0])
# Out:
# ['atharv' '1' '2' '3' '4']

# %%
data.notnull()
# Out:
#      brand  model  processor_brand  processor_name  processor_gnrtn  ram_gb
# 0     True   True             True            True             True    True  \
# 1     True   True             True            True             True    True
# 2     True   True             True            True             True    True
# 3     True   True             True            True             True    True
# 4     True   True             True            True             True    True
# 5     True   True             True            True             True    True
# 6     True   True             True            True             True    True
# 7     True   True             True            True             True    True
# 8     True   True             True            True             True    True
# 9     True   True             True            True             True    True
# 10    True   True             True            True             True    True
# ...

# %%
bool_series = pd.isnull(data["ram_type"])
data[bool_series]
# Out:
#       brand     model processor_brand processor_name processor_gnrtn ram_gb
# 52     acer    Aspire             AMD            NaN         Missing    NaN  \
# 98      MSI    Katana           Intel             i7         Missing    NaN
# 116    acer     Nitro             AMD              5         Missing    NaN
# 119     MSI     Pulse           Intel             i7         Missing    NaN
# 126  lenovo   Ideapad           Intel             i5         Missing    NaN
# 186  lenovo      Yoga           Intel             i7         Missing    NaN
# 213    ASUS       APU             AMD           Quad         Missing    NaN
# 285    acer  Predator           Intel           Core         Missing    NaN
# 292    acer     Nitro             AMD              5         Missing    NaN
# 322     MSI      GE76           Intel             i7         Missing    NaN
# 365     MSI     Pulse           Intel             i7         Missing    NaN
# ...

# %%
data=data.fillna(0)

# %%
data[52:53]
# Out:
#    brand   model processor_brand processor_name processor_gnrtn ram_gb
# 52  acer  Aspire             AMD              0         Missing      0  \
#
#    ram_type  ssd  hdd       os  ...  display_size  warranty Touchscreen
# 52        0    0    0  Missing  ...             0         0          No  \
#
#    msoffice  latest_price old_price discount  star_rating  ratings  reviews
# 52       No         54990     89000       38          4.5     3190      414
#
# [1 rows x 23 columns]

# %%
bool_series = pd.isnull(data["ram_type"])
data[bool_series]
# Out:
# Empty DataFrame
# Columns: [brand, model, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, display_size, warranty, Touchscreen, msoffice, latest_price, old_price, discount, star_rating, ratings, reviews]
# Index: []
#
# [0 rows x 23 columns]

# %%
data.dtypes
# Out:
# brand               object
# model               object
# processor_brand     object
# processor_name      object
# processor_gnrtn     object
# ram_gb              object
# ram_type            object
# ssd                  int64
# hdd                  int64
# os                  object
# os_bit               int64
# graphic_card_gb      int64
# weight              object
# display_size        object
# warranty             int64
# Touchscreen         object
# msoffice            object
# latest_price         int64
# old_price            int64
# discount             int64
# star_rating        float64
# ratings              int64
# reviews              int64
# dtype: object

# %%
data['ram_gb'] = data['ram_gb'].fillna(0)

# %%
data['ram_gb'].fillna(0)
# Out:
# 0                  4
# 1                  8
# 2                  8
# 3                  8
# 4                  8
# 5                  8
# 6                  8
# 7                  4
# 8                  8
# 9                  8
# 10                 8
# 11                 8
# 12                 8
# 13                 8
# 14                 4
# 15                 8
# 16                 8
# 17                16
# 18                 8
# 19                 8
# 20                 4
# 21                 5
# 22                16
# 23                 8
# 24                 4
# 25                 8
# 26                 8
# 27                 8
# 28                 8
# 29                 8
# 30                 8
# 31                16
# 32                 8
# 33                 8
# 34                 8
# 35                 8
# 36                 8
# 37                16
# 38                 8
# 39                 8
# 40                 8
# 41                 8
# 42                 8
# ...

# %%
data.isnull().any()
# Out:
# brand              False
# model              False
# processor_brand    False
# processor_name     False
# processor_gnrtn    False
# ram_gb             False
# ram_type           False
# ssd                False
# hdd                False
# os                 False
# os_bit             False
# graphic_card_gb    False
# weight             False
# display_size       False
# warranty           False
# Touchscreen        False
# msoffice           False
# latest_price       False
# old_price          False
# discount           False
# star_rating        False
# ratings            False
# reviews            False
# dtype: bool

# %%
data.drop(['processor_gnrtn'], axis=1)
# Out:
#          brand        model processor_brand     processor_name         ram_gb
# 0         ASUS      Celeron           Intel       Celeron Dual              4  \
# 1         ASUS     VivoBook           Intel            Core i3              8
# 2         ASUS     Vivobook           Intel            Core i3              8
# 3           HP         Core           Intel            Core i3              8
# 4           HP         Core           Intel            Core i5              8
# 5       Lenovo      IdeaPad           Intel            Core i3              8
# 6           HP          15s             AMD            Ryzen 3              8
# 7         ASUS         Core           Intel            Core i3              4
# 8         DELL       Vostro           Intel            Core i3              8
# 9       Lenovo      IdeaPad           Intel            Core i3              8
# 10          HP         Core           Intel            Core i5              8
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
data.head(896)
# Out:
#          brand        model processor_brand     processor_name
# 0         ASUS      Celeron           Intel       Celeron Dual  \
# 1         ASUS     VivoBook           Intel            Core i3
# 2         ASUS     Vivobook           Intel            Core i3
# 3           HP         Core           Intel            Core i3
# 4           HP         Core           Intel            Core i5
# 5       Lenovo      IdeaPad           Intel            Core i3
# 6           HP          15s             AMD            Ryzen 3
# 7         ASUS         Core           Intel            Core i3
# 8         DELL       Vostro           Intel            Core i3
# 9       Lenovo      IdeaPad           Intel            Core i3
# 10          HP         Core           Intel            Core i5
# 11          HP        Ryzen             AMD            Ryzen 3
# 12          HP     Pavilion             AMD            Ryzen 5
# 13      Lenovo      Ideapad           Intel            Core i5
# ...

# %%
data=data.replace('NVIDIA', 0)
data=data.replace('Acer', 0)
data=data.replace('Pre-installed', 0)
data=data.replace('Full', 0)
data=data.replace('Intel', 0)
data=data.replace('Access', 0)
data=data.replace('Dual', 0)

# %%
data['ram_gb'] = data['ram_gb'].astype(str).astype(float)

# %%
data['ram_gb'].mean()
# Out:
# 9.752901785714284

# %%
data2 = data.replace(0, 9.752901785714284)

# %%
data2['ram_gb'].mean()
# Out:
# 10.11210464166135

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            896 non-null    object
#  1   model            896 non-null    object
#  2   processor_brand  896 non-null    object
#  3   processor_name   896 non-null    object
#  4   processor_gnrtn  896 non-null    object
#  5   ram_gb           896 non-null    float64
#  6   ram_type         896 non-null    object
#  7   ssd              896 non-null    int64
#  8   hdd              896 non-null    int64
#  9   os               896 non-null    object
#  10  os_bit           896 non-null    int64
#  11  graphic_card_gb  896 non-null    int64
#  12  weight           896 non-null    object
#  13  display_size     896 non-null    object
#  14  warranty         896 non-null    int64
#  15  Touchscreen      896 non-null    object
#  16  msoffice         896 non-null    object
# ...

# %%
data['msoffice'].replace(['Yes', 'No'],[1, 0], inplace=True)

# %%
data['msoffice'].iloc[0:]
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
# 5      1
# 6      1
# 7      0
# 8      1
# 9      1
# 10     0
# 11     0
# 12     0
# 13     1
# 14     1
# 15     1
# 16     0
# 17     1
# 18     1
# 19     0
# 20     0
# 21     0
# 22     0
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     0
# 29     0
# 30     0
# 31     1
# 32     1
# 33     0
# 34     0
# 35     1
# 36     0
# 37     0
# 38     0
# 39     0
# 40     1
# 41     1
# 42     0
# 43     0
# 44     1
# 45     0
# 46     1
# 47     1
# 48     0
# 49     0
# 50     0
# 51     0
# 52     0
# 53     0
# 54     0
# 55     0
# 56     1
# 57     1
# 58     0
# 59     0
# 60     1
# 61     0
# 62     1
# 63     0
# 64     1
# 65     0
# 66     0
# 67     1
# 68     1
# 69     1
# 70     0
# 71     0
# 72     0
# 73     0
# 74     0
# 75     0
# 76     0
# 77     0
# 78     0
# 79     0
# 80     0
# 81     0
# 82     0
# 83     1
# 84     0
# 85     0
# 86     0
# 87     0
# 88     0
# 89     0
# ...
